# %%
import numpy as np

# %%
data = open('sonnets.txt', 'r', encoding="utf8").read() # any simple txt file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }
# Out:
# data has 94275 characters, 61 unique.

# %%
hidden_size = 100
cell_size = 100 # cell size and hidden size should be the same
sequence_length = 100

# %%
Wx_f = np.random.randn(cell_size, vocab_size) * 0.01
Wh_f = np.random.randn(cell_size, hidden_size) * 0.01
b_f = np.random.randn(cell_size, 1)

Wx_i = np.random.randn(cell_size, vocab_size) * 0.01
Wh_i = np.random.randn(cell_size, hidden_size) * 0.01
b_i = np.random.randn(cell_size, 1)

Wx_g = np.random.randn(cell_size, vocab_size) * 0.01
Wh_g = np.random.randn(cell_size, hidden_size) * 0.01
b_g = np.random.randn(cell_size, 1)

Wx_o = np.random.randn(hidden_size, vocab_size) * 0.01
Wh_o = np.random.randn(hidden_size, hidden_size) * 0.01
b_o = np.random.randn(hidden_size, 1)

Wh_y = np.random.randn(vocab_size, hidden_size) * 0.01
b_y = np.random.randn(vocab_size, 1)

# %%
def sigmoid(z):
    return 1/(1 + np.exp(-z))

# %%
def train(inputs, targets, hprev, cprev):

    xs, hs, cs, ys, ps = {}, {}, {}, {}, {}
    fs, ins, gs, os = {}, {}, {}, {}
    loss = 0
    hs[-1] = np.copy(hprev)
    cs[-1] = np.copy(cprev)

    for i in range(len(inputs)):
        xs[i] = np.zeros((vocab_size, 1))
        xs[i][inputs[i]] = 1
        fs[i] = sigmoid(np.dot(Wx_f, xs[i]) + np.dot(Wh_f, hs[i-1]) + b_f)
        cs[i] = cs[i-1] * fs[i]

        ins[i] = sigmoid(np.dot(Wx_i, xs[i]) + np.dot(Wh_i, hs[i-1]) + b_i)
        gs[i] = np.tanh(np.dot(Wx_g, xs[i]) + np.dot(Wh_g, hs[i-1]) + b_g)
        cs[i] += ins[i] * gs[i]

        os[i] = sigmoid(np.dot(Wx_o, xs[i]) + np.dot(Wh_o, hs[i-1]) + b_o)

        hs[i] = np.tanh(cs[i]) * os[i]
        ys[i] = np.dot(Wh_y, hs[i]) + b_y
        ps[i] = np.exp(ys[i]) / np.sum(np.exp(ys[i]))

        loss += -np.log(ps[i][targets[i], 0])

    dWx_f, dWh_f, db_f = np.zeros_like(Wx_f), np.zeros_like(Wh_f), np.zeros_like(b_f)
    dWx_i, dWh_i, db_i = np.zeros_like(Wx_i), np.zeros_like(Wh_i), np.zeros_like(b_i)
    dWx_g, dWh_g, db_g = np.zeros_like(Wx_g), np.zeros_like(Wh_g), np.zeros_like(b_g)
    dWx_o, dWh_o, db_o = np.zeros_like(Wx_o), np.zeros_like(Wh_o), np.zeros_like(b_o)
    dWh_y, db_y = np.zeros_like(Wh_y), np.zeros_like(b_y)

    dhnext, dcnext = np.zeros_like(hs[0]), np.zeros_like(cs[0])

    for i in reversed(range(len(inputs))):
        dy = np.copy(ps[i])
        dy[targets[i]] -= 1

        dWh_y += np.dot(dy, hs[i].T)
        db_y += dy

        dhsi = np.dot(Wh_y.T, dy) + dhnext
        dcsi = (1 - cs[i] * cs[i]) * (os[i] * dhsi) + dcnext
        dosi = np.tanh(cs[i]) * dhsi
        dosiraw = (1 - os[i]) * (os[i]) * dosi

        dWx_o += np.dot(dosiraw, xs[i].T)
        dWh_o += np.dot(dosiraw, hs[i-1].T)

        db_o += dosiraw
        dhnext = Wh_o @ dosiraw 

        dcsi += 1
        dgsi = ins[i] * dcsi
        dgsiraw = (1 - gs[i] * gs[i]) * dgsi
        dWx_g += np.dot(dgsiraw, xs[i].T)
        dWh_g += np.dot(dgsiraw, hs[i-1].T)
        db_g += dgsiraw

        dinsi = gs[i] * dcsi
        dinsiraw = (1 - ins[i]) * ins[i] * dinsi
        dWx_i += np.dot(dinsiraw,xs[i].T)
        dWh_i += np.dot(dinsiraw, hs[i-1].T)
        db_i += dgsiraw

        dcnext = fs[i] * dcsi
        dfsi = cs[i-1] * cs[i]
        dfsiraw = (1 - fs[i]) * (fs[i]) * dfsi
        dWx_f += np.dot(dfsiraw, xs[i].T) 
        dWh_f += np.dot(dinsiraw, hs[i-1].T)
        db_f += dfsiraw

    for dparam in [dWx_f, dWh_f, db_f,
                   dWx_i, dWh_i, db_i,
                   dWx_g, dWh_g, db_g,
                   dWx_o, dWh_o, db_o,
                   dWh_y, db_y]:
        np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
    return loss, dWx_f, dWh_f, db_f, dWx_i, dWh_i, db_i, dWx_g, dWh_g, db_g, dWx_o, dWh_o, db_o, dWh_y, db_y, hs[len(inputs)-1], cs[len(inputs)-1]

# %%
def sample(h, c, seed_ix, n):

    ixs = []
    x = np.zeros((vocab_size, 1))
    x[seed_ix] = 1

    for i in range(n):
        f = sigmoid(np.dot(Wx_f, x) + np.dot(Wh_f, h) + b_f)
        c = c * f

        ins = sigmoid(np.dot(Wx_i, x) + np.dot(Wh_i, h) + b_i)
        g = np.tanh(np.dot(Wx_g, x) + np.dot(Wh_g, h) + b_g)
        c += ins * g

        o = sigmoid(np.dot(Wx_o, x) + np.dot(Wh_o, h) + b_o)

        h = np.tanh(c) * o
        y = np.dot(Wh_y, h) + b_y
        p = np.exp(y) / np.sum(np.exp(y))

        ix = np.random.choice(range(vocab_size), p=p.ravel())
        x = np.zeros((vocab_size, 1))
        x[ix] = 1
        ixs.append(ix)
    return ixs

# %%
n, p = 0, 0
smooth_loss = -np.log(1.0/vocab_size) # loss at iteration 0


# Adam optimizer parameters
momentum = 0.8
decay_rate = 0.9
lr = 1e-3

params = [Wx_f, Wh_f, b_f, 
          Wx_i, Wh_i, b_i, 
          Wx_g, Wh_g, b_g, 
          Wx_o, Wh_o, b_o, 
          Wh_y, b_y]

m = [np.zeros_like(p) for p in params]
v = [np.zeros_like(p) for p in params]

# %%
while n < 20000:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+sequence_length+1 >= len(data) or n == 0: 
    cprev = np.zeros((hidden_size, 1))
    hprev = np.zeros((hidden_size,1))
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+sequence_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+sequence_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, cprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print('----\n %s \n----' % (txt, ))

  loss, dWx_f, dWh_f, db_f, dWx_i, dWh_i, db_i, dWx_g, dWh_g, db_g, dWx_o, dWh_o, db_o, dWh_y, db_y, hprev, cprev = train(inputs, targets, hprev, cprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001 / sequence_length
  if n % 100 == 0: print('iter %d, loss: %f' % (n, smooth_loss)) # print progress
  
  grads = [dWx_f, dWh_f, db_f, dWx_i, dWh_i, db_i, dWx_g, dWh_g, db_g, dWx_o, dWh_o, db_o, dWh_y, db_y]

  # Adam optmiizer
  for i in range(len(params)):
    m[i] = momentum * m[i] + (1 - momentum) * grads[i]
    v[i] = decay_rate * v[i] + (1 - decay_rate) * (grads[i] ** 2)

    params[i] -= lr * m[i] / np.sqrt(v[i] + 1e-8)


  p += sequence_length # move data pointer
  n += 1 # iteration counter
# Out:
# ----
#  WdcJwKoqoFmt),rO?cqJwTFP
# d?TGJ:?i-uDUojD o.h l:jJFqdFlp?rcl-nJ?do-EoryWoF?y(lmo-poziwhAw?ph(.dKPvOziKpW,!tDoTm?psqe,dFIdoJeGdALF)oWm:rOIuPw ocuwwwS,-Tzg-Y-KqbwpFg?-NS?Rp-Bk MGCis-om)c:o-cdv?I oSOkPpBo
# ----
# iter 0, loss: 4.111328
# ----
#  imsimeysdt wr 'eootff tice tc tRc rne un
# o oan ddo
# tthunn
# oof- eeroeior oaa hybmosaryetOimol
#   uotvai  moteentya.cpt riufw
#  , rgrndlinyenuaysoeemayns donyoapftwteedissr  eesrngeeror dmyeova uua
#  h m
# ----
# iter 100, loss: 4.039562
# ----
#  r d r,elrfisrest
# eflleg
# ooyin,tn oeee igioardltyelrlnBhd  eeg oyv.teh lim lheeJtm b a
# io fyenfgtfeh hrieeyy  Gmeeeteoghdryth irAieto'he,dWt y ,dhe gesgsu
# nefl
# m svths i IhflAor
# t fadh  itloe
# gti
# ldey
# ----
# iter 200, loss: 3.949955
# ----
#  iecw
#  yge  n lieroasept ttayunuWlieneeee Bthtetofm
#  ro npcrays itw im dat eqa sn reeeaneystrd rant,bby en' i  e  sloayt i h t r yet
# ngyeomhosfrfc, ht ruewifdeAsg ed rnotfeideeeeasyt,ir maiuy yn l ydb
# ----
# iter 300, loss: 3.864234
# ----
#
# e 'ofisO tcoranc,mhrtnsrhoeweeeo A khe ra,a eh ssildlhWc,ht sesghrdu
# e ywidreT gn
# nau nnlslfsw,h oStonl shre dlrswalWiodrt'mlerroa,kdts  ,athe pyhhv ut l a baoei,aleaifd t e osuga net ;qfnuI e  tt ga
# ----
# iter 400, loss: 3.787677
# ----
#  en t:ct . ore liicIplyetys e noore  h
#
# laceeeer t.b e p,oaho ws n,
# fiiBsetinue;h owroulouhornnlh wymho
# sr hne slo piww eyehae o ea.ipui od w,ue ehAsh'l cerdee etor rfadat lt omvs ro psn oge ,dieOhe h
# ----
# iter 500, loss: 3.712132
# ----
#  ekeeseitees fwhsprh gsunnehibgue hoh le SaOit -tFsLdengr rrlmwo Mgr
# dwua
#  n.eouy dmn ttiagaftal,hkonr jrisehhes hI
# onseeohatonmehegite,
# esywrot hhe he r saBoyeeirsIosos tytafus tunhn rorldhee glsin wA
# ----
# iter 600, loss: 3.640247
# ----
#   eerownisr s pem  leislhampst vtuhtpt ivoml t veocIv iruy o wade nyg etnyod th oooht i ciritestsatsi ,canaisy ae ,o npc arr hr lo,bt
# donwrs eoit rdoetat
# vlrame oyos wheyadiasfs  tgf hilirmhgl codheh,
# ----
# iter 700, loss: 3.568854
# ----
#    teTbhI t t,ed he  pe,
# the,p lh.samn c ee t ath tsemes hhethfi re  ns,s e  kith a n y,r
#  ainve
#  ha,h cr h mtstemlsiaei
# d a st s d srbenk s d t dr eae,drmi w r nosd Ah u'asc Ap beus s yis da s
# b hut
# ----
# iter 800, loss: 3.499406
# ----
#  se 'ot g t,aehtyenac
# oy mlype eheg gv siBn ,eede wfsggdoerelgw id n,gos iyeyy Sest ,n'aaurc les,
# moaifh l krteseourhe Ih whalorymaie iI es cty mi to n lfvhd t th ouret yin plih ooasihn.oll g y ,
# ihd l
# ----
# iter 900, loss: 3.427453
# ----
#  el mmsnthi'iwdtsy uo uu tuott whlihene,
# lhauedwo
# wi atati Aid .ueesam nhlnfh whiselwsg tawer IonfrlsogaliadoF
# nadf vossenwut sueee uousibs dfs tahtalts dh hounew the ghiptohcitaf fof yh s aloog fe nxe
# ----
# iter 1000, loss: 3.360363
# ----
#  e
# t.
# yomnafa vayh vhes te ps are merb ns
# Oe,
# otot diapnile ug nlasacgv,
# Wif wim
# We azob d lrowroshry ehonyosI fo s nti ue foik pe bad the,,ov we ny
# sk thpm dr rofod th wo d ln, me pteaot d tatodhcuowl
# ----
# iter 1100, loss: 3.294804
# ----
#   st thy rgiaa grabothabv,
# coor opsesey ah wepey sr,
# aon soe whahla, dho:o t ny,
# so.
#  itot th.iigosdiceori nphigogy,
# dos re oy eras mudeitt te inn
# s me thathas if oth froarse ho
# pon
# iathac l tit llht
# ----
# iter 1200, loss: 3.230296
# ----
#  renloet dfndr, ofisian ye not tho,
# lere
#
# wheifr.
#
# shean,pol i n inehe dd ce aloc ngele
# p'e osun ooedvd diind pot le theg phelnygtvepouveamr omer te, keduos vhe gl thallor,,
# Tfinct ye diy whon -n thivh
# ----
# iter 1300, loss: 3.170849
# ----
#  e
# OounueBs d thefe rahan nheps smtid'whkfe toinosery tr set d ceit tnmitut,
# aor drd whetis fy safthow bif weonst botes thevee al'etpe nhemov men.
# uheodAif,t,
# Tirb w wit  t fanf ane Iasil weioremloevec
# ----
# iter 1400, loss: 3.112497
# ----
#   os uf teenes honl rofy lun uh en ort neamly ghele oeeaworn t mee leo thor lmeriyirl orou hd m thivecy,At anreg seuhg wine,aoret  toe sideertl hr vr cors set ineaosy asd.avalnu st t laners ihofedeacut
# ----
# iter 1500, loss: 3.059818
# ----
#  rimrt onirs hon doy le roe wann
# S shem )in wbaire, boce chiswre anond tosee thiy soede auv shod anof minoI thoBs gheaew'veyes,
#
# hosl may maunoinvost,rd enlin.nde,
# pl yoratu ay uous r thosns orecpsu To
# ----
# iter 1600, loss: 3.009771
# ----
#   rhevactyt eas ot neos whe aly lain d uro s bherrdda onghd lat d
# Fthliwa wot an,
# Oetoum fy lfom pssr lintdad tirs to ney riat nd ibe, lutheIe wosheb oud vy lser mote vhbes inorast ah e brye syot tot t
# ----
# iter 1700, loss: 2.962690
# ----
#  ly?ucinm,
# youm cos angay Netgor aevams oft,
# Anmgeuy y me eye y.doe yuy nhyld thag,
# th, whe, Whet,
# Thid thy s tof syeviIe bidppy gaw meu aw thacltoles, m the tno:
# Asorg bfel se.
# verp nre an uifuwa thaw
# ----
# iter 1800, loss: 2.914260
# ----
#   se thomd:
#
# Wom,
# Whaleut hour insarkod Le ed eh lub ir,
# Whh,
# Mal de n' ce aug mituret weabmek thosh oehetin phih mold,
# O th harn mow th nhe wot thin,
# Tond hiratre, thil
# mow iriBe siil.
# Shemsnv bel, lo
# ----
# iter 1900, loss: 2.870552
# ----
#  at onk isc nrrm hame than no eeing tres hore th fimw be, oravet: mouthowe,
# mol
# Whiur mivat int l be grrattlind geen ferryo thbelins go y heeng  oruLd icBwtse ss:
#
# Tr'sneu aone solgi theul shy pnir orr
# ----
# iter 2000, loss: 2.830668
# ----
#  thy vo ithe
# d leen ,
# Woun w hant cvernd theru thigou n sells fvel vanvy th weg sofe stthalg tie kr oud nt aoot iicerle thit Mad thcor oe se'd the'te wule gn heigt wyy wive bealy  haot bnduraprmacmesf
# ----
# iter 2100, loss: 2.792794
# ----
#  get misateF e eathitilo puwh o nifun thame deirerr m
# coreasrir mash of thes hofy th erler thind vothetee fo hev heen nom elss ausf, Io muule wel,
# The ghal wourrlo gar tisev th reury thor thet pratg ce
# ----
# iter 2200, loss: 2.755447
# ----
#  ive wiffdoud hilus ns earw het hbuum on son sens wint, the mvenc iuilindir shts wouve.
# T y ahiseroulh
# Wsh,
# S
# Tho btiu to boee,
# Whel
# wane be
# d yesy ds pe ly?,
# An leon aand sug,
# tho de
# misews,
# Ficeindin
# ----
# iter 2300, loss: 2.727059
# ----
#  rean ir deume.
# I
# Or rotly subsesy it dois,
# N iuy lor lwere thek theuit and ponde choad met tid,
# gh
# Therlk.d mounl ars saro try wins y lirintt tyoe nra whahowee n yimo torir rer shau gperfaate thire
# ----
# iter 2400, loss: 2.693877
# ----
#  thust toul bsttof ire fey,
# Tiog cyy hs,enk as nsit wa tyat,
# Thens covl hant bend pneparond,
# Took uhya pyoneam ind isby ogg lhapoushom wotug,
# Whirlgritdic sl'chety thus bif,
# Sn y eivees oudfofdes.
# I
#
# d
# ----
# iter 2500, loss: 2.666232
# ----
#  a do godes elit an
# To k rone I plet tout, ss wyyin lesat.
# os vladeet go sel'ndocths it nvey :
# Ando blas f ar ahend,
# On, d wtyost iot Bht mid Nlos ind,
# arifndr yint heange gease s and int moisdiluf fe
# ----
# iter 2600, loss: 2.641334
# ----
#  as he Ie thelsd:
# Ay  fe yetee nides wou Inhg yucint recese so altare shinegret Ir ht gaderke weoI krr thabt,
# Therese dy becn,
# Fiy ths te bfr yes
# dal tupy houl shar ware urevesif bine th feotr.
# I f tht
# ----
# iter 2700, loss: 2.617134
# ----
#  lto the noweowtf hhamtr wouls they th,
# Bo thye imin touide sy seth
# AnI cyeuun res lint,
# Iigheoren fot dind wy mdea gul b theitt shakr mbug cy ne aacT or thy itwou bole .on.
# An av leuut,,
# Whanl tev mew
# ----
# iter 2800, loss: 2.589379
# ----
#  r raprm beutl lo tam,
# Sr kerld thevet wy nreed and ank ye duar con hare ces,
# Tpeif towe,
# Whchy sy lomens yosd moul badgepett' vee?
# .
# Thk find it ghof ther phaid, thoufiwe pilt isde bichenloved nort.
# O
# ----
# iter 2900, loss: 2.568673
# ----
#  sensige wrsenl naorug mithuy cangtr on srase my,
# Wsaf iy'gh heye,
# B day,
# Anis mise sots in ori shet.
#
#
# to nurist thyof dlor dadleeme tha shoteot,
# Tin ilast waweis dold thie gr'ttelpmegh iin Issrrify d
# ----
# iter 3000, loss: 2.549808
# ----
#  gou,
# An ing thol hred,
# Fo toch missn me erond owat ofot
# meoa lfat,
# I mfeon sthavagu naey mes to shen solet luhthh vabs pyod,
# Tharsus ke gowhosr tha myn, mast veesd ser I lim abe thetits ssre hoss, kry
# ----
# iter 3100, loss: 2.526065
# ----
#  oreded. nhda: toug
# Ang wot who brir orergw yainsedthon pocy ther veins Thith loct yinee,
# F bame gyoun hufe chert lo,
# ns.
# Ih ind ocetohs,
# N
#
# To padlrann hi.
# Tt beand ns sori ml, wit aley nt dy mit owin
# ----
# iter 3200, loss: 2.509187
# ----
#   chetremare lmindawligs lthecin lyeg'shimtegethe,
# Ah,
# Tofe theptoe rly minoty fnic
# Mow ilerered srintlend wf olawtereereere thyfavetr
# Sor parlamt lyaen veal l inpaclewe y atals,  fril thstyo' oflden s
# ----
# iter 3300, loss: 2.491228
# ----
#  ousheove.
# wos th aren ing ar ghast ith qoal:
# And,
# Send mil bl sy ml litho sror an,
# Anme ntins mpe hake,i lars iwoil eing the okevi hh lpl,e han arale pcingeathith yeacsthan nlaregrath lntharing af mes
# ----
# iter 3400, loss: 2.475564
# ----
#  suwur enmseen sacedr?lo do tourle he,
# Thee a my al.
# Mo tave fey yseestem, Anorerecerd the to anfs on,o' ghapstlalt ne inceeangot pis yranh veomtah lelig iman er  arye yothandereeet y ye alst ehelt ou
# ----
# iter 3500, loss: 2.461931
# ----
#  wecle,
# Aid,
# Of bould tich f aimte bndef il tha met idewt on fowt la ten bochd te mor mave higorl otcen t hores,
# Wids teowte badl, thicssth we treemtesd ith ips.
# Thindurldo tatpfur the me,
# Wpalgh thy i
# ----
# iter 3600, loss: 2.451637
# ----
#  y,
# Worekune, Hels chey deart ougye houe.
# Bne wofad.
# whestust tharant chirith nlor ing ove man whaern, sowh fy arot no nellt uiuc npas caoth t igsrags yihe te tous sefilk naes ssest inlge ho,
# And uisne
# ----
# iter 3700, loss: 2.434642
# ----
#  vises chey my whe be've chine orost,
# Oreulkl dle.
# Mask be hthe siok muusth'fe woveash fuik mloeitid bedue dh yh cheiselceum'f oun, sonweige cwtthe 'm minl,
#
# o reto Ald oneun nestmingwikstune thedsy I
# ----
# iter 3800, loss: 2.423644
# ----
#  chave s lofics one hu thichelorrt noundenasfe llemid theng sove' pideot ad mas'd,
# Mon tighde eret asveth,
# Thalf oniks fisely fsendinge'gl thace llpasewrue,
# Sol ml.
# Bi in th
# And tove,
# Aner vyou'se, I s
# ----
# iter 3900, loss: 2.412724
# ----
#  esu mes lan oses have.
# Theses disk tho ou thath bohe trer this lf, thesn igno t omid irl:
# Thes livid theimthit d,
# Fov wheome thou melar dous thersth woy tat shme.
# S, miss boundet tis iw.
# Thou brims to
# ----
# iter 4000, loss: 2.401229
# ----
#   thean hith ou orens medin thy,
# Thount tanten, onande ghe,
# Thiye singe on be,m htslay, arsrou sparel dofont witing tom tht sare,
# Lo is bom yeecut dove,
# An powh thane these sut ssceat pacs seitham fat,
# ----
# iter 4100, loss: 2.387641
# ----
#   bo loll.
# Heus myelde swigh
# me mf bup bicd to the ame,
# Th thouf tou I stis sry aned an thesighis' touks gave, hy ronth  ot tho sths cfrera.
# Arel efepalsa thett dy,
# Aning ale I shoul bbane sth siellt k
# ----
# iter 4200, loss: 2.381151
# ----
#  per douathend in yott mersth mekem, mlwi wout sthath rrend kyee s yre ceve f ou lnd sout pine sofede.
# I t?
# Then tork n inthud aringr end isd
# Thend,
# ares,
# Sou tor pake bat fyor af win sorve yh sof fid
# ----
# iter 4300, loss: 2.371012
# ----
#   bamse engal aslt foth
# of lon cewhew dideve chiilt, whel's dowet cor end meme my's, mig, os cho baty sidre.
# hins souy fe me,
# anl samakef mes the dounoverl sbesss ththe,owr'd ghave lane,
# The thess prac
# ----
# iter 4400, loss: 2.362293
# ----
#  o no saffwelsts sthe,
# AnT
# Thalits ot treruchy the ines bt ary me'w ored easss suuxll tou berteus toff pilotn heerc forr'ssr asgroves bedueth hing wigron senvee, ar lfingriog the lande drting les ive i
# ----
# iter 4500, loss: 2.355817
# ----
#  pald fake s lo hund io fayt the ove, tea, greict een sovd,
# Whs st arald thith lel that tis dins, win wulo fieve.
# And' los,
#
# I no peife mi,
# I ore tine adi th ing ceatot hi geturt weikle the dlil rerees
# ----
# iter 4600, loss: 2.347232
# ----
#  ar y feang fove ssh mthin an now ghich bal, sout thser foughe df tof mawh st the wheve, I are prat.
# Th eld, yy,e.
#
# c fost thas famdo thes ind mat inof thind,
# And thouink, weangpincy is wat thy seith t
# ----
# iter 4700, loss: 2.337285
# ----
#  ngse, Ofwr thy ghat re,
# Andando the.
# Wut,
# A
# Norer wor ghent d,acgdl'st,
# Nouf girou ai.
# Necu ind bfeaspte's lree the lat pesenes grereocst thnost:ore re sthe,
# On seutit atbut nin:
# Bv eece,
# h
# Ond thisk
# ----
# iter 4800, loss: 2.333129
# ----
#  t heanderot hide'se uray ey abe to moalsento dot were mato cnoprd t-aras non seeteld ing,
# Tems ingor byeee awines condye fuy sowave,
# k ky,
# of wapese,
# Lon tho levears ta cest sweous mi fis glenesemI wi
# ----
# iter 4900, loss: 2.326563
# ----
#  lon I my abed,
#  hessa th ist orill foret fom tey bomee mee,
# uniget ish, hees mteat Theald''st asene swave mde louec ode, mathyth arovet wrint artheihd nfistsuree, th movyut:
# Any taptheat thit thin has
# ----
# iter 5000, loss: 2.314864
# ----
#  sd tow love simed sulturll kit oskid, ino.
#
#
# Soun.
# So thasul ith
# d.
# An wy balsued sad thald e dosre beline, wrome mo anes kisdil s argero efachse of fochermind y laed bee noveth ihs yod,
# Tho owt yairn
# ----
# iter 5100, loss: 2.311761
# ----
#  in and wredoumis ne miwheghal bero owy,
# And thor wondened tharf anguston theith fiwhrert fok souge tiind,
# To thom t a
# Halc whapeat grielasu sadcitl lay cow, hy waere teik gilly,
# Whit meses douts seinw
# ----
# iter 5200, loss: 2.303776
# ----
#  wrom so selat, wong onorke thas me pavese wheit ufrether s o aeld bno dye, e
# sunde wart ould,
# Ante yn yor the,
# cely agdo und to gerod doresigris word ertwsusesust augrase,
# Singepith opat: or ?
# Bnos wa
# ----
# iter 5300, loss: 2.298094
# ----
#  yle I whid perse,
# I me's sot mberor, fowed ster le.
# Whoued dorer yo cheremus bmloug thor to not ary pove tolf whejer mwo semew cimeig dof in no houl soth imine ultes le octe thes lort.
# I dot secal gre
# ----
# iter 5400, loss: 2.293485
# ----
#  ss's hill orkers moresk't wrimen cith sioeth,
# Thist,
# Souekese stl thisrr chye sath ped in veke Ind hat of pimlat thid,
# Thoor thal.
# Oren sow, I o tho sin athom wive nol liml me an dor:
# I dicr ast yote
# ----
# iter 5500, loss: 2.293008
# ----
#  On. pou thast thaw.
#
# Th pofydend port mbed,
# ar slou wawes Iuf that pald ah hewigh'
# ang hyor If Ir the fon wiing goth hapes oke bu, tede marth I, moul
# Thesellanco coo seitl thar dno the andos polt no
# ----
# iter 5600, loss: 2.282814
# ----
#  bve,
# O blink thend,
# My talind ritest bis cang torru thienges lore ols wour thutres,
# Thea rtey cine wive swise,
# Asto't dinh shive
# The dey pacfin uneme, s bye ou hest thand:
# Crast mais ked seenow thy th
# ----
# iter 5700, loss: 2.279932
# ----
#  hape:inl tithyt thagn the nis ares is we weenostcto cafutt,
# Bule ofor plares teire heold noundee  falighes ang lyind
#
#
#
# Thr abe,
# Bost mousald the's y iny love whike,
# Indss thain dyece siksist Iatt's b
# ----
# iter 5800, loss: 2.272764
# ----
#  im wees,
# ay maste thiss thith,
#
# o amis thie, ke,
# ceas thow sreags blat hath ingred thit mo mit, pistht nth sale chines seany' milt,
# A
# Tho
# Whave,
# Wiint teest ithes then ich lesd selechu mast my sirerue
# ----
# iter 5900, loss: 2.266360
# ----
#  eed uetaele serest mirt yh fowin wrorec sir arel rorls alalov toflt noume theipr owhe ein pome mend ind touth aned,
# Whou fove n wrilles vespath, wingerhity cuy dil erour's myis he eamt,
# Aly tho mtasis
# ----
# iter 6000, loss: 2.260293
# ----
#  hy mon en bo medes,
# Homeeds manun t my thy minl lond, tatht f abem,
# Mo ghatne cou daus.
#
# o se tur alics doeo agreangou thou alke she bove wof aof buto rett, he wKy coug usige os mave riccaitat my und
# ----
# iter 6100, loss: 2.256261
# ----
#  emon teith math ige: thy my thy fade foug barc,
# And ant the lan ey stece fof anded,
# if buchh rilgos tis quchinos wons ofn note dengathe, rogeve my whenghing fily sudged my forth ly cs an ched hat, wo
# ----
# iter 6200, loss: 2.251506
# ----
#  ond:
# Hay verelss irlit preeds inus bige,
# Whit mim opreut hore tho douv,es gelar ancdese, for I jpachady ofyu bu.
# Ond cflint leacl bedent loug,
# I myy lued fovthss,
# il of meremy elran wou'ki then I whea
# ----
# iter 6300, loss: 2.247530
# ----
#  eerst lathed war whife.
#
# Siy beiv mime bous tsuy ang how cit chom for mis thiig,
# I cig avesuwe thas lf yorin's machrten he thor sor istat y mraded sorowst m tade fixs ly ancs my bisl ant mirst balllce
# ----
# iter 6400, loss: 2.244959
# ----
#   wpourts dothil,
#
# O imm y suis, ay wait mowis risis, yos hoy I did,
#
#
#
# The mmerre bl the tht yo hy thed I byo the'ise by and se,
# Thit t ongrisg sthern satket be ganelrs uaw thy th wase nove-th be seed
# ----
# iter 6500, loss: 2.237613
# ----
#  he'nd arucheideprot y
# Thaan seinlog yocgild yo forise,
# Yof orir,
# I dy sfou sood tuld.
# wnigithy why ngy rathen
# ar garow y erte fer'chy rof theith Thelis ivi gal oit,
#
# Whl do wane,
# Wacessed y diy toug'
# ----
# iter 6600, loss: 2.234123
# ----
#  epot thit the yorepe pans
# Nad satr drane,
# Wempe be sich's bu hinur thar upo thounl so anming seeraly byal famy ay  shoncsradsy worrided fforeng moughe, last sin tra becal eI d oal hou wey stith ry le
# ----
# iter 6700, loss: 2.230915
# ----
#   soul guleat ghill lco dove fengheros mo id, enf mye thor hy me'st ove prielg's mmuca the t.
# Whemfreseld ari finght anc impin thou I co ptinlvan dietaghale mins deeay tute,
# Asd tith,
# And the breestr l
# ----
# iter 6800, loss: 2.226194
# ----
#  r art,
# Ant my wroto role,
# Srakes deas peasd cipee geil,
# And or wore dor the ster cald srost ming thave cutr thart sannestdet the
# ak dos deay trame.
# Wit,
# cappomt god,
# O dedhep ny mand
# Whou tour.
# Bret
# ----
# iter 6900, loss: 2.216089
# ----
#  ,
# in lisstot o walfershe dovend,
# The bremy sord thous iflvefelo kinet,
# I plis,
# Fow thoul fhest,
# Wh wiwhurl be areins fost fuint gast,
# ust
# Whight serimengn my whiseme the,
# Angomt'tos ghey thighathove
#
# ----
# iter 7000, loss: 2.216621
# ----
#   mangne
# Why corndumm shoust thin dro grlend gay,e midacy flowgy meares-th beac thith heuld eeryul shing corle,
# I hor I prat,
# Thet hyed so wusw, imy preugke' sereneat bloscl owh wrveeve angenes,
# Ic aim
# ----
# iter 7100, loss: 2.209130
# ----
#  olly antely Oret lom'th mighy plinga thene hayey what dorf roven ustus muno be ravisten wereest soum turpa,,
# Bu ar frree,
# Ir hauet my chat dake loun,
# By womm hil trof seand decextredp:
# And iven arie t
# ----
# iter 7200, loss: 2.204945
# ----
#  ring mlor, and eald seels cound.
# The veitind, then pallice, at heat hedt tho spill prow, my thy nunom frasst Iuke,
# Thy fodes bink me sise pond soun cove,
#
#
# fe I pveredo core,
# Theme theagt mucm a myedy
# ----
# iter 7300, loss: 2.202019
# ----
#  hick wusy kr if hiprems tiy
# Tharend dath
# neds in be Ive
# Facecwt migh seand thumut, hpesusn or busts.
# y meaco faey
# Nounr he, lisnld.
# Noakess as the hin seigo nl caawsen alt cive man succhtrom man of s
# ----
# iter 7400, loss: 2.201158
# ----
#  e st.
# Or hads,
# and gowlt:
#
# nse agl sied,r thiy dar thll fithe vit o beart:
# And me I whe besighich scase th an thon whe that fete o is iphess ay larith of bres lother thou love and or fat plyee elinger
# ----
# iter 7500, loss: 2.193187
# ----
#  nf sith beeedo diet fores thou ond,
# Nost fot ic tobl gart.
# Watn whakns' feswengese'ssuni
# it esuls thy fomf drours fallf, to fulenls by bive,
# Athy thouber
# Wettn talld ongt hot romy sede sins mor hy ell
# ----
# iter 7600, loss: 2.190972
# ----
#  re ttire I poly,
#
# O gabe beallod,
# O feer yover's whinen trapld swald deevss hyo tha t awenge me:
# Fyour thit ptith mu be fint ou monsire dow sot rold hertoubt whithe ise,
# Onour itst on toor key,
# Ther s
# ----
# iter 7700, loss: 2.186804
# ----
#  wade fmy bfa't,
# I n fa thone se thave be sinct hath hot langemes.
# felbe, ah mo be bet
# Anpt, thachange fus bove,
# This thef thy ant theng,
# Nom rate scarre my mel heeame ur the dill my b'ss weaut:
# Thy mt
# ----
# iter 7800, loss: 2.179096
# ----
#  r this ay,
# And torend comy thee yo anc urach bead beyrou this tuth ar ho e, ort stoullur my toor conf yow so the glors,s mof powre, thamd, of co thy cord cis thain dot oud im duireapne,
# Seet's I fatin
# ----
# iter 7900, loss: 2.176097
# ----
#  rst sonth poore semecl my laty troustes yitith the sing veashsy bat surpendwst.
# Bu mise,
# O this uy sweoud hour fticf,
# in.
#
#
# And pichee somoust fioth all-by sut tomers nnlmowe
# I lot om wes cil bloutend
# ----
# iter 8000, loss: 2.171447
# ----
#  And chee sthe are citer?
# Ther the he ner I pring tha wriing th'n fim thou lingal whear loalt, bit minem not ferer ghond:
# Thue
# Whoulh shand for gras thaind tor esecre wirt ined thot bige?
# Bu langif ch
# ----
# iter 8100, loss: 2.167078
# ----
#   tlatove, nese.
# Thim me anes erphowe sn urupl er,
# Fod ory and, and ank and dryove do am'ed,
# An in mpild nove,
# Coort,
# I dead tho ifurs siot,ok yof ara futorled se wme tha min kat ming en it hil thou,
# H
# ----
# iter 8200, loss: 2.164462
# ----
#  orel gallingem, arve swaye,
# Searedn,
#
# Wron ly heruustht thou tos suebakh bun theaute seest veenkse to arl thou thanct mety wind,
# yet  abe,
# Whe oncwersssif nom-s andeds  onderss,
# Tom, st thiins youedry
# ----
# iter 8300, loss: 2.163998
# ----
#  ld tous ald finto kntt in hat rean br theass anle,
# Buvest thit syo hyor oretougs kn wisty.
#
#
#
# Ind sueurted haxedikn suly is inouse lathsund, wo yot searstst
#
# Thee inse't I merrives mish and eraks spa
# ----
# iter 8400, loss: 2.157062
# ----
#   foor how mus past en stir u buthe whedome surred rornt?
# And bunghee thiteang o veand sound be wertink end br sowlcenoul'se, erers mors buth I lloca lime,
# My thea dingh so so row:
# end.
# Wh mligere, puc
# ----
# iter 8500, loss: 2.154901
# ----
#  rise? sees ne thaf gacer a if doen's bassist blend sore sorr thinge of l's sthesse,
# All thind if cruealcured dour womand I fougros winghigy  hand yom nct corngrey aell,
# Whakt gerins bunecure houty, no
# ----
# iter 8600, loss: 2.153196
# ----
#  outhis hou folgifdne of bomtoung dor wearse thou of erodns yeis my cowersorad. how wakus meilbs serelld,
# That sort.
#
# That honghe das yoot to ten tiked sureved, say ood ovei-is hid an sedskalpurt thear
# ----
# iter 8700, loss: 2.148626
# ----
#  g te.
# I singove.
# Ald thar sero of urice and begine I ast ant yecemy corerd meres yn e of mane steurg mime,
# I dous neint myess nitht he whas thad atlin to thined thie ghor heof wrind in eveed,
# Sicere p
# ----
# iter 8800, loss: 2.140356
# ----
#  efh
# And ent.
# Fope ast defte of in tomue she aince bere's, thy whive onsicued,
# Whe laut armo tor hiwiru whlors salld sereanis a
# Fou wreil ich-erut aghen ho farsingnd shay wactere love gors sais it
# Wher
# ----
# iter 8900, loss: 2.141442
# ----
#  omy enesthin th of thouin dour wild inke ay cos hay it whencond, bee have hacis mest stor dith plike orthin deamy ime.
#
#
# y tichis wiy lofty u
# Olisust asee why benked endst byaus,
# whit wouterute. Therw
# ----
# iter 9000, loss: 2.134908
# ----
#  owne.
# That whang sembeasdoress In dind, y ald, whauly sor me lovesd, as yose my ont eallwst,
# The dove,
# Tint,
# Andes mty ster she an as gherde ase-y mvestrace haelton suese,
# Mlomy uy thast,
# Whot beneee
# ----
# iter 9100, loss: 2.131464
# ----
#  ot or menigly to si thens mo tume of mbnet yo s blor'sen  hist nos tine?
#
#
#
# yo w is ligl yo turint rod im covein pust bithat te whaspenwe thy ber,
# An ocond drest
# My to to dame ast me do the wome thits
# ----
# iter 9200, loss: 2.129775
# ----
#  fut.
# I whes thay thou me on mis?
# and, the fince m matlns avend re my on is mixsselet be lleamy, crave.
# The it in telduet
#
# Cot no ind dor wover that stous, nout bery catl,
# And thee
# bute
#  ficepsswel und
# ----
# iter 9300, loss: 2.128527
# ----
#  n I blanles ac mankse wisf loves ountsul wholland sued.
#
#
# Bnt my thes those
# Bused.
#
# tuml pivif no rothins lack hamen ain ensesam, to kelong thever keplirn telor worn peaveight shou hat sees ming:
# Thi
# ----
# iter 9400, loss: 2.122120
# ----
#  her cor are or and gparend,' st no ath brarid tith hud peien be tereing do mo ith feares the thy tris habe,
# Mpenats chid ightishy
# fise bref cined tey dof rire,
# ones efll wnow wemeet.
# Saisple twy meret
# ----
# iter 9500, loss: 2.121988
# ----
#  amend,
# Trat frame, ank fos thame lapp tout thair hale,
# Thathy's cot my istheds thenth derode,
# Fat undef,
# yo than moor shain,
# Fo lo blogr porfe nwiby that  ingen's en meruty,ur whand tore lyal w:
# An bi
# ----
# iter 9600, loss: 2.119710
# ----
#   klepinge If withs ares en theave.
#
# And es rorted or gainse at I bris eermss.
# As woth the my the live, so winest do graced ilet lond dith thend falld,
# But thy shodn.
#  ot coun und'e, ho the und os dai
# ----
# iter 9700, loss: 2.113185
# ----
#  ,
# Bo groul iarth fn cheplluyss fike les wrpestyoude ho trow theecot the nod los,
# Thee rarn rades he spats byece com dind whith ow troulir my what tirs inguts tho sule mived.
# Thout:
# And swy pist,
# Ate f
# ----
# iter 9800, loss: 2.111758
# ----
#  dirlsed amesl thill whatin tist spath.
#
# So thi h llast, of wille whours, pinike uthtr thast tond ares.
# And vathth'r buvlove,
# Ands spearsted corpondoundn at wheetine theit ty sty,
# diet ond so of fricke
# ----
# iter 9900, loss: 2.107273
# ----
#  orase dase whyed th brearllorse withy sigh, core, salet dramed siote,
# To i lovell,
# Aljur,
# ive wleace ouret you beaith,
# ceres my ersisks devenpe I tous obe pidly, nour tomast welldses,
# Ast thy my tourd
# ----
# iter 10000, loss: 2.103564
# ----
#   sind,
# There thing be or hiet guld sweard tuut mist bear er mave reat ith my beast ape thers porgemy ben to Ind worlike hnvem,
# So t.
# Mo brall bukice prenel
# And mave the geavig ar theat co awond I swae
# ----
# iter 10100, loss: 2.102252
# ----
#  ve caccor,
# I tale ve, in, the, ruthy fead wro gefuses,
# Or wheer mact thave pill, of thal suncwer'nd at astiue thune,
# To h and alpes mreed,
# I lounk and siy's.
# Anl bo gor peiweg seast to raknk to buigke
# ----
# iter 10200, loss: 2.105165
# ----
#  te I that enas foth praurs yor me thale the rodremo rich and ape sall that  here foteth,
# But to veee,
# Hor hows shess-ong peith, fre maicl of ther dith blast se fitay the suspaes to pthou sping dost my
# ----
# iter 10300, loss: 2.098961
# ----
#  e ullof aprenss mgilly ar bein tidit fo spowh's ine wwairg cuth late,
# Wouc.
# Fyou the linger to hide swingine demy butul whoueins ly,
# Lease wheed.
# Bo nom wrescetthbe tinve w,idll uthise daingerut
# Whe
# ----
# iter 10400, loss: 2.098794
# ----
#  t lino love nound wisp sears, eo deavh my the lour,
# And, delle.
# But anong woline in drocest grane.
# Thon wnou akn mlef fur sulcths fryese,
# The have llonsur's that ded surs thave ldsorss on thot wa ly t
# ----
# iter 10500, loss: 2.096721
# ----
#  nd thor freeag bare thusut,
# Ho shis to lo now, ir ine than tines ferrithee thars,
# Nith duter aas wreat with prour  ul ot thus eling thes p love,
# Asm ye agn cenatg if featt the anghos thin gagl conve I
# ----
# iter 10600, loss: 2.094123
# ----
#   sey baice dor aid nound s'ave ceary mordlesedse sidy bthse dule wrutigl ly, of iseels o fully sove so hous the ther bees.
# Wheaurjue ar, I thee me youn stam,
# 's tabu ice thibt loss cays wime ing me ul
# ----
# iter 10700, loss: 2.088931
# ----
#  .
#
# Fo key forst flone by thou dope.
# Loth wake hencer haitil ith wo pherd kirpl I thss he touned tise pe beauth rat of than whaic sied ait ght m mofut as's 'hes,
#
# the tnou m the ich bess, my thas
# in
# ----
# iter 10800, loss: 2.089233
# ----
#  ptinest hiwh con os streay by mimy prasting,
# Maig an that mares sosscl's neoccken somke hove  thout burumoustorot outhouth elld be, fay lake momy ar micm is ened wist mort,
# Whout s ece menall I blend
# ----
# iter 10900, loss: 2.084933
# ----
#  fate bith thy alt uh see war hent ik cour hes nov grent reefl wom crooke, yragir endergicon doot, nebe bres,
# To lory, mou maput, has manw will gises' now whes lourme,
# kie.
#
# Thow dus wneererest angr ec
# ----
# iter 11000, loss: 2.082529
# ----
#  e,
# As sertand ssaclin mith rushirs poot sleesish the love wrove, wir menf mong of wiill vin oft as that vee a mofms aisehe thy mist if ho cha seosn,
# Searou e my torin of beendet frarst benddey d sall
# ----
# iter 11100, loss: 2.082890
# ----
#  t sidul, with yot men wiwh ty the mlouuny in wey bury lotlbe,
# O ty gothee of hame a thy cancobe wrlike wire,
#
#
#
#
# There thous fove of treen be wach aty tinto of ingel's be thut senes, no reausce,
# Fist
# ----
# iter 11200, loss: 2.080261
# ----
#  ringuon theine that thing what foughtrrae ay awitich's elethy if solm shad sinot I nos tten my no be, my in whetem suuting dotroust furnpert fordingr that ten's I dnat sime,
#
# Thee o them yed bad,
# I of
# ----
# iter 11300, loss: 2.077328
# ----
#  e mendly. and the o as beals mlese's the hithe rit illat of melos thy I thy fale, nase veed tingse chi prine's,ge tour chale pande cath y tial imy,
# I bote.
#
#
# That that thre beessleg agorere sodst,
# Tin
# ----
# iter 11400, loss: 2.077956
# ----
#  reacend:
# br mlotit shoug by awh wound meak hecl mingee ad broon now bre.
# Whice avee
# ine shough therml me d say,
# Thin thous deese onet of fury on mo tisur braule tpo.
#
#
#
# y
# Thit on s angen himyer'sof el
# ----
# iter 11500, loss: 2.075039
# ----
#  t nit the fokesdr I sey tresu fuecis davtres my asply,
# Antce the,
# To d loinghaug that wivingy thee suen love luthidet lit to streaged ncing alole.
# I thel to manty yor love thad  tort thacin dee,
# And i
# ----
# iter 11600, loss: 2.068028
# ----
#  with boragif thiecerest
# Whove riratid det welt.
#
#
# Thou sherted
# Thee und han my of swast int my roth thato the ghaite.
# Whingeln vhes dightey no ast the tor
# Bll thea wroutels,
# Angeth,
# But jut serve. hor
# ----
# iter 11700, loss: 2.069297
# ----
#  heded my moke povented
# My heand.
# Sine bored sosmis hourfule cang,  ill-ans,
# Whou nonco hingute lloet a muich show my tiet limerned uthest thit lligore fant I tount mish myed my serst atl,
# Thit the way
# ----
# iter 11800, loss: 2.065255
# ----
#  reecore ast moth's maths tree wrice,
# Mfor thou meych with dee's to abe thent'ed shacht wend feed womaure rour fom,
# Serorstir tom sutat,
#
# feat aotige and, whe shet yow, a lonrice,
# Thy youn dayd,
# Then t
# ----
# iter 11900, loss: 2.062700
# ----
#   that I bered susp ware nove balll mams ore's jeat prod,
# O vose muse fandead vair thte  faild thee thlinge word em fondonge hregleee  gaivcol me pware futhisbon tror Tort thaing toralis uruef caday,y
# ----
# iter 12000, loss: 2.061489
# ----
#  auch fidserduns dil swith u bon whe faks the Ir wsusts  som forst Iics I welind ine tausu thut am frendeald steicy,
#
#
#
#
#  s it ther ir werof of me, foulcy whor shet yee,
# Whimin loves th acort you aon w
# ----
# iter 12100, loss: 2.064687
# ----
#   my tor thy spains, for dutket-anl thes treme veew,
#  hath m ryoust,
# And why I fore.
# What shail
#
#
# Who bulld thice ald furights beverr,
# To inge this beings I bether shath co ceals fiple mand cat I kapl
# ----
# iter 12200, loss: 2.058919
# ----
#   -eavene theed bucha a the allenl fyowe bice so ferenth I culle by, spy thou thee wil and wrexd foot lore,
# le beving tor foun be fin the of thinty hith an thainget, trespingen't bath nou dowtst
# Eorghb
# ----
# iter 12300, loss: 2.060261
# ----
#  ach wis fu thou hemould,
# Thing ast beaplas gramt swainge timin.
# The theed yot that ind that lligihe?
# Whee fiely blirto hor thy gowy heem faed amferyea,
# Anble ofin bee fuy?
# my seft yout,
# hough hike,
# To
# ----
# iter 12400, loss: 2.056123
# ----
#  egr thave, whit shouke dne wibutur,
# Ant buth pare's tobee sall us came mw thale,
# But me thine that if mat fion, yot mt mouele nothe,
# Whene thre will hos
# Andse,
# What note girf murn id nnt my in thean
# ----
# iter 12500, loss: 2.051919
# ----
#  ughthe, sile doos  ime cheroued by is me elecern wor as my o hyau haig depristsim tor a wiresant ow dhain besiot bepry.
#
# your be wind of and tho an this chomuuft coup.
# Thou worf iking thowenrs,
# Thy is
# ----
# iter 12600, loss: 2.050087
# ----
#  at a goond ith meem fith th then yee,
# As lavtt, thou ow thoue have seyed and hy dues wile
# And ight of be malt lad,
# I men way berom warels,
# Fon tree beis sond pade whear,
# or shachy,
# Or prowopk,
# The sin
# ----
# iter 12700, loss: 2.047248
# ----
#  ut mell,
# Nin mm lire sovtir thour to deedit monf in helosout,
# Which an that ar blimef, be lid withaie tor thout ther dyered  wrishad proant onol vime of thou thor scove sith mersnew pearne of mae of a
# ----
# iter 12800, loss: 2.045453
# ----
#  uwil wreriou,
# Thas ecby ofh that in tor and in mee
#
# The lovere frowiy hink thee ther Tave myep'ed me wich beabep vere beishe beathe, niaghe, e
# Theas.
# Fon wat.
# Lith sey fobery senst
# And yon zey, lun'e,
# ----
# iter 12900, loss: 2.043934
# ----
#  d corgotht of frutcond of rearast,
# O ling an thisp forsings an mily nonk mif surstut fraites swid on man onks th doth houn' art by pincgry fthou pith thy muhm shave piok  ampenter wrytstrengs tie or l
# ----
# iter 13000, loss: 2.044206
# ----
#  e
# Andes hake thel und thy most hive therpll fllrien hat me mey thei guth mthese theln in my hinghas fat, elin of is ull leef.
# Whe lowir d:
# And to in ous feesty bes fiid my hit theart ch ighinnd tris s
# ----
# iter 13100, loss: 2.040745
# ----
#  pr whalow,
# Noldes founf thes bence ryige waistr if levene me ctoren pake thy feras,
# Whe rroustart,
# And prorealik ssowst:
# To del pavtiend loves.
#  farecny.
#
# y thy noo tith,
# Hath chor, is or ghacd annty
# ----
# iter 13200, loss: 2.040917
# ----
#  tour.
#
#
# To sle-thicin theall co dingad,
# And ingr raweet
# youce art borteest aco grasof demes I love ay theed on of all mer popleed on ien ulave of thy dor I Thou now allor bie,
# The oas love ofld pullse
# ----
# iter 13300, loss: 2.039897
# ----
#   yo be that nod I far love sime ricod to rith co greseving ly stare, wea grild to ho ghay of kemy shomcel, rnout thet with all in fem,
# Ancelir suor he of me tlees seande,
# Whe losaikse fontered,
# Siose
# ----
# iter 13400, loss: 2.037593
# ----
#  ham to dacend,
# But in that art in sh thy sthe trat my star e forunds a a menctar thoughre wie weart,
# Sime butt then ssalor 's seladss the bray stoou, op lurss prove wit ill hiagr wrom when my of t ank
# ----
# iter 13500, loss: 2.029894
# ----
#  pprvence cames and,
# Whasses in bet ilp?
# To pimenglowe,
# Bit pich's hor sold,
# Thy fomy sive spycheld proulle,
# Fo ruglel
# Dais by se,
# Froull bust,
# in thy the kis not,
# Bor save thy with eaumy on heangerrof
# ----
# iter 13600, loss: 2.032803
# ----
#  as dadedull thise tee frour,
# Anouright yith lountwoou louls love,
# Srech knlo t amo doure trichow in beirnr frit the beat upd mith in ot.
#
# Butine huthe they hang witefy beated
# of go be isepave hencay
# ----
# iter 13700, loss: 2.026971
# ----
#  I lemy me alt to robl nlas or sellee.
# to deer,
# And ull wild dyed tha pall.
#
# O he ceck slest dras me waguld
# Buth me wtall at sty'e,
# Thay to to bullle ade,
# And thet love
# Whon hyounds o rand my, froor re
# ----
# iter 13800, loss: 2.025436
# ----
#   tuth the porsome wranughtu thos weakess buthen eve, that dyer tous,
# Fong dorf on to hotin peit a becifing my gowthy dowerst, be hove,
# Fo
# Hat
# Buth love, the my sway, 'n borlled,
# nidpt me seespt enci
# ----
# iter 13900, loss: 2.024826
# ----
#  harind with thour drount,
# That fores pico, of thin thes the, thero u I knoulyss of not no har my thy,
# Higltrs sive,
# That ullle.
# nou has strreare.
#
#
#
# To me mas ecknse be, futir vat the pilllour to ell
# ----
# iter 14000, loss: 2.026209
# ----
#  nes be feade.
# willd an spaingle frale brlane ase plllednem thears kiks yon urust than is fly tonk to, in ilet's hith meirs noms wor.
#
# kt sh to thel
# My wive tome where the sodnin thom day th tont's in
# ----
# iter 14100, loss: 2.021128
# ----
#  'ss,
# And meegled o
# Than dats feard'st'ssees heac:
# That do bovidr berithe to mivtse,
# Whenour:
# Why ine faver's,
# The shose caithe,
# Ank frait ther and: prouteriust and owned whoess ightown beoume's wherie
# ----
# iter 14200, loss: 2.022035
# ----
#  hase'n suld, fatith bligh and
# Butror I sanft th no do sost aning my sode nor wimis tid swit i
# Whill apther th er ot love.
# Liald the sind with cortif my wey.
# Whing not my call,
# to le.
#
#
#
# That shate.
#
# ----
# iter 14300, loss: 2.020119
# ----
#  o sun,
# I love swanth yos on with dong thou love ten thatetour roly mfal happenge,
# Than tor hatipee,
# Ate she thusu mases ereed,
# An in with:
#
# Fonow?
# But mast thy henced to wote the d'sham amechied, ad t
# ----
# iter 14400, loss: 2.013917
# ----
#  eade thot wusarlen moull imo but?
# Bo thougulerse notr hopedsuring to fore thing of gasuale'st mo stell,
# Beach your an thate thom,
# Ford brair tith aich bearndse,
# Whing ting live,
# And of and the, that i
# ----
# iter 14500, loss: 2.013937
# ----
#  o nsm the but thee mo dlich,
# That nove dith 'strongs ingill thach doud,
# My leall swick sold eaket hinde what me kon to formuguly why of coptere,
# That my go an.
# Snow fer not teay, healte:
# Ther Ink in h
# ----
# iter 14600, loss: 2.009891
# ----
#  bn dach len a gram the antle this of ag praye,
# Tigh bronc brill, hall besed theals watheech mete faith'e loming,
# The bestith fonts
# o hatatuy price,
# vin tros thes donce the levy will,
# Alongt, woret,
# Fo
# ----
# iter 14700, loss: 2.006946
# ----
#  ne but not timend noth dave iin trese.
# Mak dolin' port, the buch love as my peaking lit arud thintar seat, iu I wel of wsen thingureds dach wnor delfpled domkit meat,
# And may,
# The tatestcanse then sof
# ----
# iter 14800, loss: 2.006402
# ----
#  Ate
# as nove grumast by sad tant fot on
# Sor ayd wret at to burt ingnline,
# and it tree, bor toou, of horgomb terr,
# Or to ssule kint salles, chy ene youede buptharsers fulled.
#
# Nids ne mived thy wuld
# ----
# iter 14900, loss: 2.009582
# ----
#  ared thenl,
# Oru beams and peyone simy bus in thee I not betefer henow,
# The's Ifle on dise loveswre rame fness ict allike eneres, and suell jeop,
# Will shat dime ontones comn.
# I ravat yoo thes felede is
# ----
# iter 15000, loss: 2.004082
# ----
#  teed,
# Than where thesel perverith, trus mied mond.
#
#
# And selemide coth solselld noume fall sove,
# Nor alvilt If since y livter tind, how ing sh welof lodse come in wo muncere teey do ben stecer shase
# r
# ----
# iter 15100, loss: 2.005327
# ----
#  y.
# That thicen lune sostest'se thou woon day a she foon rlon thul a rook yor thou o grecons dimene,
# Wheir and by astinour's ditureme what shand thach mas ther's binged.
# wy lourtand thy whear now at hy
# ----
# iter 15200, loss: 2.004160
# ----
#  hee hearnd sithed leake: llove poor manded theing bath uth carn numis a the bus worth the becr aimosedr mestiens my'n seld the leas by thecain,
# And trisends eiret somed,
# Atoul:
# Thouy mectht.
# Whe be pe
# ----
# iter 15300, loss: 2.001590
# ----
#   arot theaikl,
# Funound,
# I ando me leoven it in batin forcess if ledef seauthionde,
# Foof my be whesbes is wetry my seucer age theme dome gutheil, rearts side, weraited beimt,
# To mert,
# Nanse steasele fo
# ----
# iter 15400, loss: 1.995170
# ----
#  h shaist the sor hamill,
# Asbe seed mend love by my.
# Anvere,
# And,
# All spagctor  werseed mive,
# That manl dreverm adond, bicr of the on now to grefe cove bears wilctoy sulf dowt dimeee rover seost bealt
# ----
# iter 15500, loss: 1.996393
# ----
#  lay, id parum's, hoth nexpravin's widetde tarin endess wirdon shost dise,
# The beille beve thich is thast.
# The cow tayl'r cong dour,
# Thires thou vichist athir wied In, for obn my owseds,
# That hour,
# hep
# ----
# iter 15600, loss: 1.992475
# ----
#  atg in datte ouftring bufing hromest deldsst sell,
# That ofong th thes tingute shay y spoush tese pore os I bughllave hot 'se hif veerses of he, ture time now ake cich, Thy shan gigrpay cond llearg.
#
#
#
# ----
# iter 15700, loss: 1.990245
# ----
#  e of terig if cone inde dowe:
# But frich beagrntw pulpst deppive both not the ?
# me tlirig yot more famis abing ald mle core-stas buscer peat est deswe, yos bay seners: in stound.
# Lid my levear shtarst
# ----
# iter 15800, loss: 1.990903
# ----
#  d to tine,
# Thy me ole
# Thiile,
# She, and eee's,
# whing merungrw cond cait is the brily,
# Wit, you in brenage,
# That fartant beect lore swar soket thy love beadsead,
# As my sege dneck,
# Whe on chount.
# What of
# ----
# iter 15900, loss: 1.990477
# ----
#   meer'sted kea ab tinteabour,
# Than wece at shy dormmind,
# Winst id see,
# Tif eed jeve, what rellss me, the's thon lith pain hold owet my thicaing nen it welftith nre befor faprt:
# Andse gime to do shoul
# ----
# iter 16000, loss: 1.985543
# ----
#  outh:
# Mhat knon thace hen I ro ro steve or wriones's so nem shech taf of loved,
# e sull foo har with bet I woule to andonteds, prich lake my mond.
#
# For woulard,
# As the I hrate.
# you wie. sul cheest
# Thou
# ----
# iter 16100, loss: 1.987424
# ----
#  haves then ald me ketrane,
# Why thou lovied,
# That whourestde grantiest,
# Thy hit de of ace ditl,
# Loth, wo weam thy eedme tand I nenound hile tath owal beithedn prilde,
# What eef hith ith,
# Asd an tere i
# ----
# iter 16200, loss: 1.985792
# ----
#  thy lover sefter thowel my ged:
# ere to gaing gromourts, boo de my ertowe, or thous thes thut ssolsus.
# Or stild est is hath mine be thor chee liedm, she becomarsses with done verake.
# ghin cingintses my
# ----
# iter 16300, loss: 1.979725
# ----
#  But  ace not ainghr minks ofal by tuing.
# And wed face bacaurmen'see aree broor,
# That git nemose ink, not then whow of cheidhe al arvir the il toth nour hit, not bevinst lath, bo thos frounpen kep and
# ----
# iter 16400, loss: 1.979254
# ----
#  ,
# Then thee diss bewing doe imt carn to nove to pesay,
# As vooted thear,
# Or tr's of frourb,
# An ce toned, is I dour that so sresee love blifall geeed, be tror by livo eir mfourith with seivene
# So thou y
# ----
# iter 16500, loss: 1.974966
# ----
#   that ased tunse they lagladpy such ppeolid eivell of, a dron as int siong all plooned decpy.
#
# uth hest tood ay ol cong the ofomer's somseer pay is firt, shom the,
# So ant of thoule ra tovesst to that
# ----
# iter 16600, loss: 1.972853
# ----
#   my stovered tautes and ite.
#
# or I my pivered
# Aredist
# Thouleds yot pould of chack igrteance praged shen cove nent,
# Lhowns lefonis lote dense ere-tcet ost tould doove thince kiond sult indt wheill gote
# ----
# iter 16700, loss: 1.973017
# ----
#  echtergs,
# I spith ey foll ong, bloving menk man buturfre lovoued I bysume ow live ingrare, a be rivest art ig rive fothet yill hery,
# And mpal ake keing, rnouk
# Nor whith a toou wurn yeef fritist:
# Wilt
# ----
# iter 16800, loss: 1.977095
# ----
#  l ces,
# If livere eble,
# But by joored paks'not firuse if not hea thome that I not frechet boodsseran peat ien the hest bend are tith with thu hay ufpity sure tendse torm avinty is me puibceve veenf thy
# ----
# iter 16900, loss: 1.971519
# ----
#  us nesbe of brisestrre, and crades erise,
# Shot my witl the pastakighth beir thillt akern.
# And meast,
# And forist om no not tortiel with thouing aretarse,
# bet-eabce not mat crould flingtelioug noughit n
# ----
# iter 17000, loss: 1.973192
# ----
#  thath thy a dove ulave yesad.
# Lot hasen
# Fon it is frouigets his myes as ath ch?
# The besul's ow cofl,
# Whore of fur
# And eever hafughold had and drelle ctare winton as thee the be, tich stoiningh the sol
# ----
# iter 17100, loss: 1.969438
# ----
#   me,
# Swimy beard eove pores nothef pat of as I cashon tauntich magtes dach with  sack tich muspided old gom of toel it'
# But braure.
# Yitith to deal mer, a shairst therele sumer being,
# ere that liceres
# ----
# iter 17200, loss: 1.966960
# ----
#  t comoryes digh let ronghton seavere muetift sulst,
# I paced hiched.
#
#
# To non wiph and far I the whes heisto's cench love howed ow my hourigh and the I with, all nast Horided
# And live pride hastintes
# ----
# iter 17300, loss: 1.963947
# ----
#  our the antike 'lloos be when thy befing wast so bland whus or the sose eyterd as of cwill os when his I rosest eyd.
# A shatty thow word of sent'mul me biid a my sery, of itmpid stomer dower fy the hak
# ----
# iter 17400, loss: 1.963021
# ----
#  u cos thour what crove,
# To bolss firsen pove s bear in have rive h sconcting,
# To mer though the the sainke,
# ead solded, for notht hom well in sutwille som.
#
# and I thy come,
# Fuserow,
# fnis the wey matht
# ----
# iter 17500, loss: 1.959752
# ----
#   wor this prattiedg,
# Maven brees if ors ast this chougy,
# For in with ind anduses thero this my surcenf Ialed, ewold bugye loven vithy sumong of ligh weer theiseing re them of I foar net bespere.
# But
# ----
# iter 17600, loss: 1.958869
# ----
#   shouss in taicy ongering thes fro weilln ghloake sell,
# Sill ay fit theed wlicirest o netrengech,
# And,
# To the my my minl
# in yor thow mas weed ofmers ghend,
# To ag beik for tpaive seopm illmwed therness
# ----
# iter 17700, loss: 1.960173
# ----
#  ke shat unith deaniobus on theer ast alb thou for aly choulds whoucentls,
# Thy nooking my nourdans no hall not, and ast verot whes cere,
# That lovin undold cone, thee I now blifsing as thee pranke spest
# ----
# iter 17800, loss: 1.957429
# ----
#  y cabrest beake be, thing tioares
# And acey.
# Ti spait no thou powis dairn appirs ixllds so nit gick In atber:
# I shour'sen thy, at in mo ald of to deaseded,
# Thy withat far reast whece to love.
#
# But seat
# ----
# iter 17900, loss: 1.959028
# ----
#   an of shal it berone,
# Ant renrinen, no lowe,
# Tith deares the arpcers,
# So with whe gautht,
# As ure corf the, havin the wille why with the will in lich of no thy forl ind what me pilt.
# ugr sturans mith
# ----
# iter 18000, loss: 1.957379
# ----
#  ee thou thy gowtive
# But oo much thee if thougedy of ey'serong shenssed,
# Theepllus rowdurs she thilich of hide act lighe cond,
# And the hoonim cauls the seartights win that then wort sheith voll tinge.
#
# ----
# iter 18100, loss: 1.955562
# ----
#  ster  wort thach stay,
# At thoug to thaucd a knfay my fantin buth spee that thy dinty od are, that my that wrearthings iny thy well bo hencone,
# Shat leres crokle not,
# Wigrts'r,
# And gisd,
# The hin the gr
# ----
# iter 18200, loss: 1.948030
# ----
#  oe.
#
#
#
#
# a in why in the bourves witringer bearsy is that a I whin no dorm thet lonsede.
# And appolli mingim wholy wer mas gaily tore's ting exinst my ga sensher sainingensl,
# Whin seed,  sor to toot una
# ----
# iter 18300, loss: 1.950172
# ----
#   orl arpitane.
# So what pirt thent, with sorld mise thilled which of love of my waye that  a mak ctend sim, not self stint ting streeseerte.
# Thing it heait, a bith with he thacr'stoth, hour Iedm kind t
# ----
# iter 18400, loss: 1.946095
# ----
#   preverig hass tham gain st thesu leefer ingo the buer strilled thes than uthay the shat, ond in to girssst soall it in baltent ig ong doknce,
# vighed disetey o mer the qutrerethedss theay ald beif swe
# ----
# iter 18500, loss: 1.943770
# ----
#  lt to hive do hirught if thy reame, warce.
#
#
#
#
#
#  prainss to me pawe,
# Buth I he byee shat,
# your thill pofall mine.
#
# Swair I in thee of thiet, are cay ping andee seng ypur ingyn tour groce red harly wh
# ----
# iter 18600, loss: 1.944094
# ----
#  I yeare,
# Fo me seet, freave, flores as paret not lave moft of has seair ost beirlen not,
# Iin mongn commy,
# O hor I nene wers ast wheres fack seass sheen,
# I noarn to thou pouth,
# os antime wand riss now
# ----
# iter 18700, loss: 1.947143
# ----
#  ed assed,
# For hars ich wiout shas I thus bendow thame his to thirs form along nit thy tiels hatis wingy what be spouth thy or, the Toe not trres,
# The it thy stee,
# Now beve thent wist that befances ans
# ----
# iter 18800, loss: 1.943357
# ----
#  y stoll, on thoue undun feauts,
# But with a vilf peeconu,
# in shath free delnengryss withs thy tooute, thy geaso hernoug ing lossust hiserang eme,
# O the sloude ont or and wifes to byere-bmantees thy bel
# ----
# iter 18900, loss: 1.945096
# ----
#  l tays'saghto as whan to to peringise way mefong dood chen thy waty cored besto,
# Oone,
# Anl in thy my stay,
# And my lovs's vorthough sombee my dinglaved tame thustht fars'st my'sert,
# Ath com stickes m
# ----
# iter 19000, loss: 1.941642
# ----
#  ave ow thy tain of stich thy self nour howept,
# To monatus phe st,
# Aft ming thole eme dey,
# Atut to mare talls abl hedich of bure los my deade no sing that not shasse to berper thour that say chor,
# An
# ----
# iter 19100, loss: 1.937289
# ----
#  thich add und the my of rakringed arpend cromont,
# And all thy welsis ip theasu eloed?
# For serang that ing of bearte,
# But that chee in all toray wettach fromem bupllous bay by als I batill grofipiis, o
# ----
# iter 19200, loss: 1.936162
# ----
#  hee I deast erstimis highted witht basith ess my blightthous this and aspikte.
#
# Whis cavert fanty dosce,
# But ullos deeg of mith see way my lovere ast I ma do cachast yee pokerding is deoting sustece,
#
# ----
# iter 19300, loss: 1.933197
# ----
#  my thic, werwe torunot me, leve deed treit now mofrer dad to braming winl, th hate the praspy seed in  fin this thoundous thredose move, and and ares whill.
#  I wary all arachy
# And formpliin, gryeel.
# A
# ----
# iter 19400, loss: 1.931254
# ----
#  Whim wort cands ind spea,
# To peepver hain, in a nopkyr I itht theing ealle,
# Ind, bree row ofth.
# Beach hed where baringingr duritl of sulfor seen sulf beinge to are carecrs salst theauth of acesh beeve
# ----
# iter 19500, loss: 1.931487
# ----
#   toor streat he sert, with to wchtrse timer thy froulaugh,
# thee gaive thou ming come,
# Fo drim yeswire, heard sedt trriof mirs'n my mivit to thy braet in tathted rumpey in deint, astar my ay tanty wre
# ----
# iter 19600, loss: 1.933546
# ----
#  as cill the bolet dombed of kac.
# That age to guch of incos fakel das furnoth grears. I bearse,
# Wile adon preach bethss thoue,
# Thou lote my infy me,
# Buth the weal cames
# Noud eastell I chey.
# Fouth by b
# ----
# iter 19700, loss: 1.929697
# ----
#  hou thust thes ang al lime ben way lonkling in mosh on youe.
#
#
#
# 'spyise.
#
#
# I nour thing thy. boay,
# Butfon kimuried te dave, to praids ands tieseds mumint though with of gryoure fa, pid.
#
# Thy propous
# ----
# iter 19800, loss: 1.932164
# ----
#  lows the brape she lus yot hean.
# and.
# Sthe prumheacn eve siem sul with of bling to ankee
# That which os my tingr puiled com ters of pleachs wrumpropl sest enow wight' is nosed oref it the on roves fof
# ----
# iter 19900, loss: 1.931117

# %%
sample_ix = sample(hprev, cprev, inputs[0], 2000) # final sample
txt = ''.join(ix_to_char[ix] for ix in sample_ix)
print('----\n %s \n----' % (txt, ))
# Out:
# ----
#
# Srakertit beod,
# To long wortureive,
# But earne hove gravies helones bright  leack tiow ant liofaded honened to I lighe,
#
# That of my laye the sum thow thy lovith of aris meat fend,
# O herurited rewe thy cand,
# Amy ownd ay my not to shous on tatter  as ant mers pline
# I brinedsath uthere ing eitp encold led alaks ghous whir trigisagh thing is gring 'lfobes, vingun fairfs or lime on the maver can ang thes stares,
# Tith this of munes.
# But nonour cang,
# But nrtout rimanene toseds,
# But theer thou and a wath thou houlf bewin haild gulos mightrsed,
# Mikn lighg tore pwirt,
# And whough brit dul and ist I mings'
# Savint fild sthys,
# And my uprip,
# At to when thy ariks ithte ind o nos unour sing,
# Sanchse plang sithen,
# To the I lay, a breires gamees and sead'.
#
# whingived barou love the im of an beamong as dave eve theen mey ses.
# Whou will,
# Anleds,
# kn with not his prats.
#
# Wey come not ingst did fair  of hanon,
# is mbert.
#
#
#
# Ad thy cour,
# To whe to cole fain's of worladiver bee's than to as for dies,
# Frete.
#
# Ey befur
#  trige Iul fremmerend, is yot one:
# O gawill of at for haverig wed kshith,
# Nor what in cor.
#
#
#
# tyee in that shave my hovtarakis latey thous, anch where co land.
# Sot wore,
# In ming ins waghe
# But with hearts, auir mingeer wour sioved as stlere,
# To love feeterses welf or which noulds briw.
# sncant,
# What aret shataull forroving to her peed mand grom dotfrempen thy,
# Wert love,
# Tho goower fen sonct.
# Sus fapcerente
# Hatime,
# Int earty,
# Thou hast
# Afvoug thr tand,
# you hest,
# The live stinly sar doefule cendd stoal pivill fole,
# strake,
# And, a sorshenst brieks,
# Thim seated
# And of ter hor anter wet beferent,
# Whol toy nous whice my blite
# loke thousea cove nre pick of she lavee lived both's prome pais onds thiver my of with an is the thee:
# But prouly paikee ham that ghen la dose thencralike I the my vive penet stour,
# But if my pmy my on theep to sacw'st ting, frnom ofe the hromm,
# of mong all sea is fire, wimpriredve:
# Witwrys thus nilled,
# For bamus aser-bmuns age ween masin'l retmeef grous it serth
# ----
